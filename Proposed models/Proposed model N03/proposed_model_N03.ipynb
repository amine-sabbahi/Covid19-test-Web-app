# %%
# Installer TensorFlow Version 2
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.2

# %%
# Importation de bibliothèques

import tensorflow.keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Activation, Flatten, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import metrics
import matplotlib.pyplot as plt

import numpy as np

# %%
train_loc = 'drive/My Drive/Dataset/train/'
test_loc = 'drive/My Drive/Dataset/val/'

# %%
# redimensionner les images

trdata = ImageDataGenerator(rescale= 1./255,
                            shear_range = 0.2,
                            zoom_range = 0.2,
                            horizontal_flip = True,
)

traindata = trdata.flow_from_directory(directory = train_loc, target_size = (224,224))

tsdata = ImageDataGenerator(rescale= 1./255,
                            shear_range = 0.2,
                            zoom_range = 0.2,
                            horizontal_flip = True,
)

testdata = tsdata.flow_from_directory(directory = test_loc, target_size = (224,224))
# Out:
# Found 250 images belonging to 2 classes.
# Found 110 images belonging to 2 classes.

# %%
traindata.class_indices
# Out:
# {'Normal': 0, 'Positive': 1}

# %%
# Création du réseau CNN

# Couches convolutatif
model = Sequential()
model.add(Conv2D(64, (5,5) , padding = 'same' , activation='relu',input_shape=(224,224,3), name = 'layer_1'))
model.add(Conv2D(64, (3,3) , padding = 'same' , activation='relu', name = 'layer_2'))
model.add(MaxPool2D((3,3), strides=(2,2), name = 'layer_3'))


model.add(Conv2D(128, (3,3) , padding = 'same' , activation='relu', name = 'layer_4'))
model.add(Conv2D(128, (3,3) , padding = 'same' , activation='relu', name = 'layer_5'))
model.add(MaxPool2D((2,2), strides=(2,2), name = 'layer_6'))



# Couche entièrement connectée (Fully-connected)
model.add(Flatten(name = 'fc_1'))
model.add(Dense(64, name = 'lyaer_7'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', name='SIGMOID'))

# %%
# Imprimer la structure du réseau
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_1 (Conv2D)            (None, 224, 224, 64)      4864
#
#  layer_2 (Conv2D)            (None, 224, 224, 64)      36928
#
#  layer_3 (MaxPooling2D)      (None, 111, 111, 64)      0
#
#  layer_4 (Conv2D)            (None, 111, 111, 128)     73856
#
#  layer_5 (Conv2D)            (None, 111, 111, 128)     147584
#
#  layer_6 (MaxPooling2D)      (None, 55, 55, 128)       0
#
#  fc_1 (Flatten)              (None, 387200)            0
#
#  lyaer_7 (Dense)             (None, 64)                24780864
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  SIGMOID (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 25,044,226
# Trainable params: 25,044,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilant le modèle
model.compile(optimizer='adam', loss=binary_crossentropy, metrics=['accuracy'])

# %%
# Démarrer train/test
batch_size = 32
hist = model.fit(traindata, steps_per_epoch = traindata.samples//batch_size,
                 validation_data = testdata,validation_steps = testdata.samples//batch_size,
                 epochs = 20
                 )
# Out:
# Epoch 1/20
# 7/7 [==============================] - 19s 2s/step - loss: 4.1282 - accuracy: 0.5780 - val_loss: 0.5924 - val_accuracy: 0.5729
# Epoch 2/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.4276 - accuracy: 0.7936 - val_loss: 0.4050 - val_accuracy: 0.7917
# Epoch 3/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.4238 - accuracy: 0.8482 - val_loss: 0.2295 - val_accuracy: 0.9062
# Epoch 4/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.3122 - accuracy: 0.8716 - val_loss: 0.2416 - val_accuracy: 0.9271
# Epoch 5/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.2471 - accuracy: 0.9174 - val_loss: 0.1776 - val_accuracy: 0.9271
# Epoch 6/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.2391 - accuracy: 0.9083 - val_loss: 0.1324 - val_accuracy: 0.9896
# Epoch 7/20
# 7/7 [==============================] - 13s 2s/step - loss: 0.2116 - accuracy: 0.9266 - val_loss: 0.1338 - val_accuracy: 0.9479
# Epoch 8/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1845 - accuracy: 0.9464 - val_loss: 0.0886 - val_accuracy: 0.9688
# Epoch 9/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1366 - accuracy: 0.9541 - val_loss: 0.0499 - val_accuracy: 0.9896
# Epoch 10/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1393 - accuracy: 0.9587 - val_loss: 0.1078 - val_accuracy: 0.9583
# Epoch 11/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1345 - accuracy: 0.9587 - val_loss: 0.0484 - val_accuracy: 0.9896
# Epoch 12/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1117 - accuracy: 0.9725 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 13/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.0790 - accuracy: 0.9771 - val_loss: 0.0310 - val_accuracy: 0.9896
# Epoch 14/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.0379 - accuracy: 0.9954 - val_loss: 0.0563 - val_accuracy: 0.9896
# Epoch 15/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.0768 - accuracy: 0.9732 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 16/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.0858 - accuracy: 0.9817 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 17/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1356 - accuracy: 0.9679 - val_loss: 0.0529 - val_accuracy: 0.9896
# Epoch 18/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1283 - accuracy: 0.9725 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 19/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.1193 - accuracy: 0.9725 - val_loss: 0.0490 - val_accuracy: 0.9896
# Epoch 20/20
# 7/7 [==============================] - 12s 2s/step - loss: 0.0595 - accuracy: 0.9862 - val_loss: 0.1131 - val_accuracy: 0.9688

# %%
plt.plot(hist.history['loss'], label = 'train')
plt.plot(hist.history['val_loss'], label = 'val')
plt.title('COVID-19 (CNN) :  Loss  &  Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(hist.history['accuracy'], label = 'train')
plt.plot(hist.history['val_accuracy'], label = 'val')
plt.title('COVID-19 (CNN) :  Accuracy  &  Validation Accuracy')
plt.legend()
plt.show()

# %%
# tester le modèle 
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'negative.jpeg'


img = mpimg.imread(image_path)
imgplot = plt.imshow(img)
plt.show()

test_image = image.load_img(image_path,
                            target_size= (224, 224))

test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis= 0)
result = model.predict(test_image)
traindata.class_indices
if result[0][0]==1:
  prediction = 'Negative'
else:
  prediction = 'Positive'


accuracy=float(np.max(result,axis=1)[0])
print('Prediction : ', prediction)
print('Probability : ', accuracy)
# Out:
# Prediction :  Negative
# Probability :  1.0
